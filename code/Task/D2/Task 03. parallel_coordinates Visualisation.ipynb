# %% [markdown]
# Visualising the wine dataset using parallel_coordinates and interpreting the visualisation results.
# The wine dataset is imported as follows.
# Check out https://pandas.pydata.org/docs/reference/api/pandas.plotting.parallel_coordinates.html for a better understanding of the meaning of the arguments to the parallel_coordinates function

# %%
from sklearn import datasets
import pandas as pd  
wine = datasets.load_wine()
df = pd.DataFrame(wine.data, columns=wine.feature_names)

# %%
# *Solutions Exampl
from sklearn import datasets  
import pandas as pd
import matplotlib.pyplot as plt
wine = datasets.load_wine()
df = pd.DataFrame(wine.data, columns=wine.feature_names)
df['target_names'] = [wine.target_names[i] for i in wine.target]
# Parallel Coordinates Start Here:
plt.figure(figsize=(10, 6))
pd.plotting.parallel_coordinates(df, 'target_names')
plt.show()
